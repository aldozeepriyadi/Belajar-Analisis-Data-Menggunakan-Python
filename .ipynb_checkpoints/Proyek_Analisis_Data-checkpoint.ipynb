# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Aldo Fernando Supriyadi
# - **Email:** aldo.fernandosupriyadi@gmail.com
# - **ID Dicoding:** aldofernandos07

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana kondisi musim mempengaruhi jumlah penyewaan sepeda?
# - Di jam-jam tertentu pada hari kerja, apakah jumlah penyewaan sepeda rata-rata lebih dari 3000 sepeda dalam satu jam?
# - Bagaimana kondisi antara penyewa biasa dan penyewa terdaftar memengaruhi jumlah total penyewaan sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv("data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Dapat Melihat isi dari dataset day
# - Dapat Melihat isi dari dataset hour

# %% [markdown]
# ### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **Insight:**
# - Pada dataset day, terdapat kesalahan tipe data untuk kolom dteday seharusnya bertipe data datetime.
# - Pada dataset hour juga, terdapat kesalahan tipe data untuk kolom dteday seharusnya bertipe data datetime.
# - Tidak terjadi Missing Value pada kedua dataset diatas
# - Tidak ada duplikasi data pada kedua dataset diatas
# - Tidak terjadi inaccurate value pada kedua dataset diatas

# %% [markdown]
# ### Cleaning Data

# %%
datetime_day_columns = ["dteday"]
for column in datetime_day_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
datetime_hour_columns = ["dteday"]
for column in datetime_hour_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# **Insight:**
# - Membersihkan Data pada day_df dengan mengganti tipe data yang awalnya objek jadi datetime
# - Membersihkan Data pada hour_day dengan mengganti tipe data yang awalnya objek jadi datetime
# - Pembersihan missing value tidak dilakukan karena tidak ada nilai yang hilang
# - Pembersihan inaccurate data tidak dilakukan karena datanya akurat
# - Pembersihan duplkasi data tidak dilakukan karena tidak ada data yang duplikat

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore day_df

# %%
day_df.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %% [markdown]
# #### load data day_df berdasarkan season

# %%
day_df.groupby(by="season").agg({
    "instant": "nunique",
    "cnt": ["max", "min", "mean", "std"]
}).reset_index()
# Out:
#   season instant   cnt
#          nunique   max   min         mean          std
# 0      1     181  7836   431  2604.132597  1399.942119
# 1      2     184  8362   795  4992.331522  1695.977235
# 2      3     188  8714  1115  5644.303191  1459.800381
# 3      4     178  8555    22  4728.162921  1699.615261

# %%
day_df.groupby(by="weathersit").instant.nunique().sort_values(ascending=False)
# Out:
# weathersit
# 1    463
# 2    247
# 3     21
# Name: instant, dtype: int64

# %% [markdown]
# ### Explore hour_df

# %%
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %% [markdown]
# #### load data hour_df berdasarkan jam

# %%
hour_df.groupby('hr').agg({
    "cnt": "mean" 
})
# Out:
#            cnt
# hr
# 0    53.898072
# 1    33.375691
# 2    22.869930
# 3    11.727403
# 4     6.352941
# 5    19.889819
# 6    76.044138
# 7   212.064649
# 8   359.011004
# 9   219.309491
# 10  173.668501
# 11  208.143054
# 12  253.315934
# 13  253.661180
# 14  240.949246
# 15  251.233196
# 16  311.983562
# 17  461.452055
# 18  425.510989
# 19  311.523352
# 20  226.030220
# 21  172.314560
# 22  131.335165
# 23   87.831044

# %% [markdown]
# #### load data hour_df berdasarkan tahun

# %%
hour_df.groupby(by="yr").agg({
    "cnt": ["min", "mean", "max"]
})
# Out:
#    cnt
#    min        mean  max
# yr
# 0    1  143.794448  651
# 1    1  234.666361  977

# %% [markdown]
# #### load data hour_df berdasarkan bulan

# %%
hour_df.groupby(by="mnth").agg({
    "cnt": ["min", "mean", "max"]
})
# Out:
#      cnt
#      min        mean  max
# mnth
# 1      1   94.424773  559
# 2      1  112.865026  610
# 3      1  155.410726  957
# 4      1  187.260960  822
# 5      1  222.907258  873
# 6      1  240.515278  900
# 7      1  231.819892  913
# 8      1  238.097627  941
# 9      1  240.773138  977
# 10     1  222.158511  963
# 11     1  177.335421  729
# 12     1  142.303439  759

# %% [markdown]
# #### load data hour_df berdasarkan jam kerja

# %%
hour_df.groupby(by="workingday").agg({
    "cnt": ["min", "mean", "max"]
})
# Out:
#            cnt
#            min        mean  max
# workingday
# 0            1  181.405332  783
# 1            1  193.207754  977

# %% [markdown]
# #### melihat data jumlah penyewa sepeda yang terdaftar dan biasa

# %%
membership_summary = hour_df[["casual", "registered"]].sum()
pd.DataFrame({
    'Keanggotaan': ['Casual', 'Registered'],
    'Jumlah Penyewa': [membership_summary['casual'], membership_summary['registered']]
})
# Out:
#   Keanggotaan  Jumlah Penyewa
# 0      Casual          620017
# 1  Registered         2672662

# %% [markdown]
# #### Melihat data penyewa yang terdaftar dan biasa berdasarkan musim

# %%
hour_df.groupby(by="season").agg({
    "casual": ["min", "mean", "max"],
    "registered": ["min", "mean", "max"],
    "cnt": ["min", "mean", "max"]
})
# Out:
#        casual                 registered                  cnt
#           min       mean  max        min        mean  max min        mean  max
# season
# 1           0  14.290901  367          0   96.823668  681   1  111.114569  801
# 2           0  46.160581  361          0  162.183488  782   1  208.344069  957
# 3           0  50.287144  350          0  185.729093  886   1  236.016237  977
# 4           0  30.666824  362          0  168.202032  876   1  198.868856  967

# %% [markdown]
# **Insight:**
# - Pada saat pulang kerja yaitu jam 17 sore terjadi rata-rata penyewaan sepeda yang tergolong tinggi, namun dari jam 0-6 pagi, jam 10 pagi-15 sore, dan jam 21-23 malam terjadi penurunan penyewaan sepeda yang cukup signifikan.
# - Pada musim gugur penyewaan sepeda tergolong paling tinggi dan sebaliknya pada saat musim semi penyewaan sepeda tergolong paling rendah
# - Berdasarkan keanggotaan penyewa sepeda yang terdaftar paling tinggi (registered) dibandingkan penyewa sepeda biasa (casual).

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana kondisi musim mempengaruhi jumlah penyewaan sepeda?

# %%
plt.figure(figsize=(10, 6))

plt.scatter(hour_df['temp'], hour_df['cnt'], alpha=0.5, color='b', marker='o')
plt.title('Jumlah Penyewaan Sepeda berdasarkan Suhu')
plt.xlabel('Suhu')
plt.ylabel('Jumlah Penyewa')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(hour_df['windspeed'], hour_df['cnt'], alpha=0.5, color='r', marker='o')
plt.title('Jumlah Penyewaan Sepeda berdasarkan kecepatan angin')
plt.xlabel('kecepatan angin')
plt.ylabel('Jumlah Penyewa')
plt.grid(True)
plt.show()

# %%
season_grouped = hour_df.groupby(by="season").agg(
    instant_nunique=('instant', 'nunique'),
    cnt_sum=('cnt', 'sum'),
).reset_index()

season_mapping = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter'
}
season_grouped['season_name'] = season_grouped['season'].map(season_mapping)
season_avg = season_grouped[['season_name', 'cnt_sum']]


sns.barplot(x='season_name', y='cnt_sum', data=season_grouped)

plt.title('Jumlah Penyewaan Sepeda per Musim')
plt.xlabel('Season')
plt.ylabel('Jumlah Penyewaan Sepeda')
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x / 1e5):,}K'))

plt.show()

# %% [markdown]
# **Insight:**
# - Dari grafik hubungan antara suhu dan jumlah penyewaan sepeda, terlihat bahwa semakin tinggi suhu (semakin hangat), semakin banyak jumlah penyewaan sepeda. Ini menunjukkan bahwa suhu yang lebih hangat meningkatkan minat masyarakat untuk menyewa sepeda.
# - Sebaliknya, hubungan antara kecepatan angin dan jumlah penyewaan sepeda menunjukkan korelasi negatif. Ketika kecepatan angin meningkat, jumlah penyewaan sepeda cenderung menurun. Ini menunjukkan bahwa kondisi berangin dapat mengurangi kenyamanan bersepeda, sehingga orang cenderung menghindari bersepeda saat angin kencang.
# - Musim panas (Summer) memiliki jumlah penyewaan sepeda tertinggi, mencerminkan pengaruh suhu hangat pada meningkatnya minat bersepeda.
# - Musim gugur (Fall) juga menunjukkan jumlah penyewaan sepeda yang cukup tinggi, meskipun tidak setinggi musim panas. Mungkin karena suhu yang lebih moderat dan nyaman.

# %% [markdown]
# ### Pertanyaan 2: Di jam-jam tertentu pada hari kerja, apakah jumlah penyewaan sepeda rata-rata lebih dari 3000 sepeda dalam satu jam?

# %%
workingdays = hour_df[(hour_df['workingday'] == 1)]
hourly = workingdays.groupby('hr').agg({"cnt": "sum"})


workingdays_holiday = hour_df[(hour_df['workingday'] == 0)]
hourly_holiday = workingdays_holiday.groupby('hr').agg({"cnt": "sum"})


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))


ax1.plot(hourly.index, hourly['cnt'], color='skyblue', marker='o', label='Penyewaan Sepeda')
ax1.axhline(3000, color='red', linestyle='--', label='3000 Penyewaan Sepeda')
ax1.set_title('Jumlah Penyewaan Sepeda per Jam Pada Hari Kerja', fontsize=14)
ax1.set_xlabel('Jam', fontsize=12)
ax1.set_ylabel('Jumlah Penyewaan Sepeda', fontsize=12)
ax1.legend()


ax2.plot(hourly_holiday.index, hourly_holiday['cnt'], color='skyblue', marker='o', label='Penyewaan Sepeda')
ax2.axhline(3000, color='red', linestyle='--', label='3000 Penyewaan Sepeda')
ax2.set_title('Jumlah Penyewaan Sepeda per Jam Pada Hari Libur', fontsize=14)
ax2.set_xlabel('Jam', fontsize=12)
ax2.set_ylabel('Jumlah Penyewaan Sepeda', fontsize=12)
ax2.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Pada grafik pertama, yang menunjukkan jumlah penyewaan sepeda per jam pada hari kerja, Banyak jam yang mencapai atau melebihi 3000 penyewaan sepeda dalam satu jam. Meskipun ada beberapa fluktuasi, grafik ini menunjukkan bahwa jumlah penyewaan sepeda tiap jam melampaui angka 3000 terutama pada saat jam-jam berangkat dan pulang kerja yang mencapai puncal yaitu jam 07:00 hingga 09:00 dan jam 16:00 hingga 18:00.
# - Pada grafik kedua, yang menunjukkan jumlah penyewaan sepeda per jam pada hari libur, terlihat bahwa ada jam-jam tertentu di mana jumlah penyewaan sepeda melebihi 3000. Puncak tertinggi terjadi pada sekitar jam 14:00 hingga 16:00
# - Grafik ini menunjukkan adanya lonjakan signifikan pada hari kerja yang terlihat dari jumlahnya , di mana penyewaan sepeda lebih banyak dibandingkan dengan hari libur.

# %% [markdown]
# ### Pertanyaan 3: Bagaimana kondisi antara penyewa biasa dan penyewa terdaftar memengaruhi jumlah total penyewaan sepeda?

# %%
member_casual = hour_df.groupby("weekday")[["casual"]].sum()
member_registered = hour_df.groupby("weekday")[["registered"]].sum()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))


ax1.bar(member_casual.index, member_casual['casual'], color='skyblue', label='Penyewa Biasa')
ax1.set_title('Jumlah Penyewaan Sepeda oleh Penyewa Biasa per Hari', fontsize=14)
ax1.set_xlabel('Hari', fontsize=12)
ax1.set_ylabel('Jumlah Penyewaan Sepeda', fontsize=12)
ax1.set_xticks(range(7))
ax1.set_xticklabels(['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu'], fontsize=10)
ax1.legend()

ax2.bar(member_registered.index, member_registered['registered'], color='orange', label='Penyewa Terdaftar')
ax2.set_title('Jumlah Penyewaan Sepeda oleh Penyewa Terdaftar per Hari', fontsize=14)
ax2.set_xlabel('Hari ', fontsize=12)
ax2.set_ylabel('Jumlah Penyewaan Sepeda', fontsize=12)
ax2.set_xticks(range(7))
ax2.set_xticklabels(['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu'], fontsize=10)
ax2.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Pada Grafik Penyewa Terdaftar (registered) menunjukkan bahwa penyewa terdaftar memiliki jumlah penyewaan sepeda yang lebih konsisten dan lebih tinggi sepanjang minggu. Secara keseluruhan, penyewa terdaftar berkontribusi lebih besar pada total penyewaan sepeda setiap hari, dengan puncak pada Jumat dan Sabtu.
# - Pada Grafik Penyewa biasa (casual) menunjukkan fluktuasi yang lebih besar. Jumlah penyewaan sepeda oleh penyewa biasa lebih rendah dibandingkan penyewa terdaftar, dengan puncak tinggi pada Minggu. Hal ini menunjukkan bahwa penyewa biasa cenderung lebih banyak pada akhir pekan, khususnya di hari Minggu, sementara pada hari kerja jumlahnya relatif lebih rendah.
# - Penyewa terdaftar lebih banyak dan lebih stabil dalam menyewa sepeda sepanjang minggu, sedangkan penyewa biasa lebih banyak pada akhir pekan (terutama Minggu). Penyewa terdaftar memainkan peran yang lebih besar dalam total penyewaan sepeda secara keseluruhan, terutama pada hari-hari kerja dan sebagian besar akhir pekan.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **Tujuan:**
# - Mengidentifikasi pola penyewaan sepeda berdasarkan waktu seperti pagi, siang, dan malam.
# - Meningkatkan manajemen layanan sepeda dengan memahami waktu-waktu puncak.

# %% [markdown]
# #### Manual Grouping untuk membuat cluster pengelompokan waktu

# %%
def manual_grouping(hour):
    if 6 <= hour < 12:
        return 'Pagi'
    elif 12 <= hour < 18:
        return 'Siang'
    else:
        return 'Malam'

hour_df['Time_of_Day'] = hour_df['hr'].apply(manual_grouping)
manual_grouping_data = hour_df.groupby('Time_of_Day')[['cnt']].sum()
manual_grouping_data
# Out:
#                  cnt
# Time_of_Day
# Malam        1092618
# Pagi          907319
# Siang        1292742

# %%
# Update the y-label to something more meaningful instead of just 'cnt'
plt.figure(figsize=(8, 8))
manual_grouping_data['cnt'].plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange', 'green'], legend=False)

# Update the title and labels
plt.title('Proporsi Penyewaan Sepeda per Waktu dalam Sehari (Pagi, Siang, Malam)', fontsize=14)
plt.ylabel('Jumlah Penyewaan Sepeda', fontsize=12)  # Update the y-label to a more meaningful name
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
